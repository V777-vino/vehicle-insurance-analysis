# %%
import vip_functions as vip

def filter_data_menu():
    print("\n🔶=>Press '1' to filter those who are income is higher than 10000 and below than 45000")
    print("\n🔶=>Press '2' to filter those who are got above average income")
    print("\n🔶=>Press '3' to filter rich customers")
    print("\n🔶=>Press '4' to filter above average claim amount customers")
    print("\n🔶=>Press '5' for filter the customers those who are having monthly premium above 100")
    print("\n🔶=>Press '6' to filter the customer details those who are having more than 8 policies")
    print("\n🔶=>Press '7' to get the customer records based on number of complaints")
    print("\n🔶=>Press '8' for Main menu")
    n = int(input("\nEnter your choice:"))
    if(n==1):
        vip.filter_income()
        filter_data_menu()
    elif(n==2):
        vip.above_avg_income()
        filter_data_menu()
    elif(n==3):
        vip.rich_customers()
        filter_data_menu()
    elif(n==4):
        vip.above_avg_claim()
        filter_data_menu()
    elif(n==5):
        vip.monthly_premium()
        filter_data_menu()
    elif(n==6):
        vip.above_policies()
        filter_data_menu()
    elif(n==7):
        num = int(input("Enter the number of complaints:"))
        vip.num_of_complaints(num)
        filter_data_menu()
    elif(n==8):
        print("\n***Returning back to the Main menu")
        menu()
    else:
        print("\n***Enter the valid input***")
        filter_data_menu()
        
def univariate_functions():
    print("\n🔶=>Press '1' for Income analysis")
    print("\n🔶=>Press '2' for Claim amount analysis")
    print("\n🔶=>Press '3' for Month inception analysis")
    print("\n🔶=>Press '4' for Gender analysis")
    print("\n🔶=>Press '5' for marital status analysis")
    print("\n🔶=>Press '6' for Coverage analysis")
    print("\n🔶=>Press '7' to go Analysis menu")
    n = int(input("\nEnter your choice:"))
    if(n==1):
        vip.income_analysis()
        univariate_functions()
    elif(n==2):
        vip.claim_amount_analysis()
        univariate_functions()
    elif(n==3):
        vip.month_inception_analysis()
        univariate_functions()
    elif(n==4):
        vip.gender_analysis()
        univariate_functions()
    elif(n==5):
        vip.marital_analysis()
        univariate_functions()
    elif(n==6):
        vip.coverage_analysis()
        univariate_functions()
    elif(n==7):
        analysis_menu()
    else:
        print("\n***Enter the valid input***")
        univariate_functions()
def bivariate_functions():
    print("\n🔶=>Press '1' for Coverage and Monthly premium analysis")
    print("\n🔶=>Press '2' for Employement status and Gender analysis")
    print("\n🔶=>Press '3' for Claim amount and Vehicle analysis")
    print("\n🔶=>Press '4' for Gender and Policy analysis")
    print("\n🔶=>Press '5' for Location and CLV analysis")
    print("\n🔶=>Press '6' to Heat map analysis")
    print("\n🔶=>Press '7' to go Analysis menu")
    
    n = int(input("\nEnter your choice:"))
    if(n==1):
        vip.coverange_monthlypremimum_analysis()
        bivariate_functions()
    elif(n==2):
        vip.emp_status_gender_analysis()
        bivariate_functions()
    elif(n==3):
        vip.claim_vehicle_analysis()
        bivariate_functions()
    elif(n==4):
        vip.gender_policy_analysis()
        bivariate_functions()
    elif(n==5):
        vip.location_clv_analysis()
        bivariate_functions()
    elif(n==6):
        vip.heat_map_analysis()
        bivariate_functions()
    elif(n==7
        ):
        analysis_menu()
    else:
        print("\n***Enter the valid input***")
        bivariate_functions()
        
def analysis_menu():
    print("\n🔶=>Press '1' for Univariate analysis")
    print("\n🔶=>Press '2' for Bivariate analysis")
    print("\n🔶=>Press '3' for Outlier analysis")
    print("\n🔶=>Press '4' to go main menu")
    n = int(input("Enter your choice:"))
    if(n==1):
        univariate_functions()
    elif(n==2):
        bivariate_functions()
    elif(n==3):
        vip.outlier_analysis()
        analysis_menu()
    elif(n==4):
        print("\n***Returning back to the Main menu")
        menu()
    else:
        print("\n***Enter the valid input***")
        analysis_menu()
    
def show_details_menu():
    print("\n***Show details menu***")
    print("\n🔶=>Press '1' for show specific number of rows")
    print("\n🔶=>Press '2' for show Basic coverage customers details")
    print("\n🔶=>Press '3' for show Premium coverage customers details")
    print("\n🔶=>Press '4' for show Extended coverage customers details")
    print("\n🔶=>Press '5' for show Employed customers details")
    print("\n🔶=>Press '6' for show Unemployed coverage customers details")
    print("\n🔶=>Press '7' for show Higher school student customers details")
    print("\n🔶=>Press '8' for show Bachelor student customers details")
    print("\n🔶=>Press '9' for show Master student customers details")
    print("\n🔶=>Press '10' for show Urban customers details")
    print("\n🔶=>Press '11' for show Suburban customers details")
    print("\n🔶=>Press '12' for show Rural customers details")
    print("\n🔶=>Press '13' for show Male customers details")
    print("\n🔶=>Press '14' for show Female customers details")
    print("\n🔶=>Press '15' for Main menu")
    choices = int(input("\nPlease Enter your choice:"))
    if(choices==1):
        num = int(input("How many rows you want to see:"))
        vip.show_data(num)
        show_details_menu()
    elif(choices==2):
        vip.show_baic_coverage()
        show_details_menu()
    elif(choices==3):
        vip.show_premium_coverage()
        show_details_menu()
    elif(choices==4):
        vip.show_extended_coverage()
        show_details_menu()
    elif(choices==5):
        vip.show_employee_detail()
        show_details_menu()
    elif(choices==6):
        vip.show_unemployee_detail()
        show_details_menu()
    elif(choices==7):
        vip.show_highschool_detail()
        show_details_menu()
    elif(choices==8):
        vip.show_bachelor_detail()
        show_details_menu()
    elif(choices==9):
        vip.show_masters_detail()
        show_details_menu()
    elif(choices==10):
        vip.show_masters_detail()
        show_details_menu()
    elif(choices==11):
        vip.show_urban_detail()
        show_details_menu()
    elif(choices==12):
        vip.show_suburban_detail()
        show_details_menu()
    elif(choices==13):
        vip.show_rural_detail()
        show_details_menu()
    elif(choices==14):
        vip.show_male()
        show_details_menu()
    elif(choices==14):
        vip.show_female()
        show_details_menu()
    elif(choices==15):
        print("\n***Returning back to the Main menu")
        menu()
    else:
        print("\n***Enter the valid input***")
        show_details_menu()
def groupby_functions():
    print("\n***Groupby functions menu***")
    print("\n🔶=>Press '1' groupby Coverage and Education based on Income")
    print("\n🔶=>Press '2' groupby Location and Sales channel based on Claim amount")
    print("\n🔶=>Press '3' groupby policy and policy type based on vehicle size")
    print("\n🔶=>Press '4' to Exit")
    choices = int(input("\nPlease Enter your choice:"))
    if(choices==1):
        vip.groupby_cov_edu_income()
        groupby_functions()
    elif(choices==2):
        vip.groupby_loc_sales_claimamt()
        groupby_functions()
    elif(choices==3):
        vip.groupby_pty_ply_vtype()
        groupby_functions()
    elif(choices==4):
        print("\n***Returning back to the Main menu")
        menu()
    else:
        print("\n***Enter the valid input***")
        groupby_functions()
    
def menu():
    print("\n🔶=>Press '1' for Show details")
    print("\n🔶=>Press '2' for Groupby functions")
    print("\n🔶=>Press '3' for Description dataset")
    print("\n🔶=>Press '4' for Missing values")
    print("\n🔶=>Press '5' for Categorical dataset")
    print("\n🔶=>Press '6' for Analysis data set")
    print("\n🔶=>Press '7' for Sorting dataset")
    print("\n🔶=>Press '8' for Filter the data set")
    print("\n🔶=>Press '9' for Exit")
    choice = int(input("\nPlease Enter your choice:"))
    
    if(choice==1):
        show_details_menu()
    elif(choice==2):
        groupby_functions()
    elif(choice==3):
        vip.decription_dataset()
        menu()
    elif(choice==4):
        vip.missing_values()
        menu()
    elif(choice==5):
        vip.categorical_data()
        menu()
    elif(choice==6):
        analysis_menu()
    elif(choice==7):
        vip.sorting_dataset()
        menu()
    elif(choice==8):
        filter_data_menu()
    elif(choice==9):
        print("\nThanks for using Vehicle Insurance Analysis👍")
        print("=========================================================")
    else:
        print("\n***Enter the valid input***")
        menu()     

print("\n🎇 Welcome to Vehicle Insurance Analysis 🎇")
menu()
# Out:
# 🎇 Welcome to Vehicle Insurance Analysis 🎇
#
# 🔶=>Press '1' for Show details
#
# 🔶=>Press '2' for Groupby functions
#
# 🔶=>Press '3' for Description dataset
#
# 🔶=>Press '4' for Missing values
#
# 🔶=>Press '5' for Categorical dataset
#
# 🔶=>Press '6' for Analysis data set
#
# 🔶=>Press '7' for Sorting dataset
#
# 🔶=>Press '8' for Filter the data set
#
# 🔶=>Press '9' for Exit
#
# Please Enter your choice:8
#
# 🔶=>Press '1' to filter those who are income is higher than 10000 and below than 45000
#
# 🔶=>Press '2' to filter those who are got above average income
#
# 🔶=>Press '3' to filter rich customers
#
# 🔶=>Press '4' to filter above average claim amount customers
#
# 🔶=>Press '5' for filter the customers those who are having monthly premium above 100
#
# 🔶=>Press '6' to filter the customer details those who are having more than 8 policies
#
# 🔶=>Press '7' to get the customer records based on number of complaints
#
# 🔶=>Press '8' for Main menu
#
# Enter your choice:1
# ...
